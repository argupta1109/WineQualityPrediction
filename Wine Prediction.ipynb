# %%
#Import the Required Libraries
import numpy as np
import pandas as pd #Data into Structure
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading of the File of given Datset
data = pd.read_csv('winequality-red.csv')

# %%
#Visualization of top 5 Records inside my data
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
#Classes of target value - quality
set(data.quality)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
#Description of the given Dataset
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#To check the missing value
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Coorelation Matrix among all features inside the dataset
plt.figure(figsize=(30,30))
corr = data.corr()
sns.heatmap(corr,annot = True)
plt.savefig("Correlation Matrix.png")
plt.show()

# %%
#Detection of the Outliers using Z-Score
# !pip install scipy
from scipy import stats
z= np.abs(stats.zscore(data))
print(z)
# Out:
# Requirement already satisfied: scipy in /Users/adityarajgupta/anaconda3/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/adityarajgupta/anaconda3/lib/python3.11/site-packages (from scipy) (1.24.3)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.466193              0.379133  0.558274  1.288643
# 1                0.872638              0.624363  0.028261  0.719933
# 2                0.083669              0.229047  0.134264  0.331177
# 3                0.107592              0.411500  0.664277  0.979104
# 4                0.466193              0.379133  0.558274  1.288643
# ...                   ...                   ...       ...       ...
# 1594             1.542054              0.075043  0.978765  0.899886
# 1595             2.211469              0.137820  0.862162  1.353436
# 1596             1.255161              0.196679  0.533554  0.705508
# 1597             1.542054              0.075043  0.676657  1.677400
# 1598             0.203223              0.135861  0.666057  0.511130
#
#       sulphates   alcohol   quality
# 0      0.579207  0.960246  0.787823
# 1      0.128950  0.584777  0.787823
# 2      0.048089  0.584777  0.787823
# 3      0.461180  0.584777  0.450848
# 4      0.579207  0.960246  0.787823
# ...         ...       ...       ...
# 1594   0.461180  0.072294  0.787823
# 1595   0.601055  0.729364  0.450848
# 1596   0.542042  0.541630  0.450848
# 1597   0.305990  0.209308  0.787823
# 1598   0.010924  0.541630  0.450848
#
# [1599 rows x 12 columns]

# %%
#If z>3 (Threshold) -> This is an Outlier
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
#        1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1295, 1296,
#        1299, 1299, 1300, 1312, 1316, 1319, 1319, 1321, 1358, 1367, 1370,
#        1370, 1372, 1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435,
#        1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505,
#        1558, 1558, 1570, 1574, 1589]), array([ 9,  5,  5,  6,  4,  9,  4,  3,  1,  4,  9,  8,  5,  4,  9,  4,  9,
#         9,  9,  9,  8,  4,  9,  6,  1,  1,  1, 10, 10,  4,  2,  4,  8,  9,
#         3,  3,  4,  9,  4,  1,  4,  9,  4,  0,  0,  4,  9,  3,  4,  4,  3,
#         3,  9,  9,  0,  6,  0,  0,  0,  3,  5,  3,  5,  0,  7,  4, 11, 10,
#         3,  7,  3,  6, 11,  0,  0,  7,  0,  7,  0,  7,  4,  5, 10,  6,  3,
#         7,  9,  6,  9,  3,  6,  6,  0,  3, 10,  1,  6,  6,  1, 11,  4,  9,
#         8,  9,  1,  4,  4,  4,  4,  9, 10, 11,  7,  7,  7, 11,  3,  3,  3,
#         5,  5,  5,  7,  7,  3,  4,  9,  3,  3,  3,  6,  3,  6,  8,  7,  5,
#         5,  4,  5,  3,  5,  3,  3,  5,  6,  4,  7, 10,  7, 10,  9,  9,  5,
#         5,  1, 11,  8,  1,  8,  4,  9,  8,  5,  9,  4,  9,  4,  9,  4, 11,
#         3,  5,  7,  3,  5,  7, 11,  3,  5,  7,  3,  5,  7, 11,  6,  6, 11,
#         4,  5,  4,  3,  3]))

# %%
#Remove those records whose z>3 (Outlier)
new_data = data[(z<3).all(axis=1)]

# %%
new_data.shape
# Out:
# (1451, 12)

# %%
data.shape
# Out:
# (1599, 12)

# %%
#Data Spliting into feature(X) and Target column(Y)
from sklearn.model_selection import train_test_split #For Spliting the data into Train and Test
x = new_data.drop(columns = 'quality')
y = new_data['quality']

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1451, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
#Data Modeling using Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_classificationModel = RandomForestClassifier(n_estimators=100)

# %%
rf_classificationModel.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#Prediction of data using Random Forest Model
y_pred = rf_classificationModel.predict(x_test)

# %%
y_pred
# Out:
# array([6, 5, 5, 6, 5, 6, 5, 6, 6, 6, 5, 6, 7, 7, 5, 6, 5, 6, 6, 7, 5, 5,
#        6, 5, 5, 6, 5, 6, 5, 5, 7, 5, 5, 6, 6, 5, 6, 5, 6, 5, 5, 6, 5, 5,
#        5, 5, 5, 7, 7, 6, 6, 5, 6, 6, 5, 5, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5,
#        5, 6, 5, 5, 6, 5, 7, 5, 5, 6, 6, 6, 5, 5, 6, 5, 5, 6, 6, 5, 5, 5,
#        7, 6, 6, 5, 7, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 7, 6, 6, 5, 5,
#        6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 5, 5,
#        5, 6, 5, 7, 5, 5, 6, 5, 6, 6, 6, 6, 5, 5, 6, 6, 5, 7, 6, 6, 6, 5,
#        6, 6, 6, 6, 7, 5, 5, 7, 5, 5, 5, 6, 5, 5, 7, 6, 6, 6, 5, 5, 6, 7,
#        6, 6, 5, 5, 5, 5, 7, 6, 5, 6, 5, 6, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5,
#        5, 7, 6, 5, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 5, 6, 5, 5, 6, 6, 6, 6,
#        5, 6, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 5, 5, 5, 6, 5,
#        6, 6, 6, 7, 5, 5, 6, 5, 5, 6, 7, 5, 6, 6, 5, 5, 6, 6, 6, 6, 5, 5,
#        5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 7, 7, 5, 5, 5, 6, 6, 5, 6, 6, 7, 6,
#        5, 6, 5, 5, 5])

# %%
#Data Evaluation on Metrics
from sklearn import metrics
print('Accuracy score ', metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy score  0.6632302405498282

# %%
from sklearn import tree
tree.plot_tree(rf_classificationModel.estimators_[0],filled=True)
# Out:
# [Text(0.4061874615147783, 0.975, 'x[7] <= 0.996\ngini = 0.626\nsamples = 716\nvalue = [26, 485, 499, 133, 17]'),
#  Text(0.17341440886699508, 0.925, 'x[9] <= 0.695\ngini = 0.634\nsamples = 188\nvalue = [5, 71, 158, 75, 3]'),
#  Text(0.12022783251231527, 0.875, 'x[7] <= 0.996\ngini = 0.595\nsamples = 134\nvalue = [5, 66, 120, 25, 3]'),
#  Text(0.06557881773399014, 0.825, 'x[10] <= 10.15\ngini = 0.571\nsamples = 126\nvalue = [5, 60, 115, 17, 3]'),
#  Text(0.019704433497536946, 0.775, 'x[4] <= 0.098\ngini = 0.193\nsamples = 24\nvalue = [0, 33, 4, 0, 0]'),
#  Text(0.014778325123152709, 0.725, 'x[3] <= 2.15\ngini = 0.153\nsamples = 23\nvalue = [0, 33, 3, 0, 0]'),
#  Text(0.009852216748768473, 0.675, 'x[8] <= 3.385\ngini = 0.108\nsamples = 22\nvalue = [0, 33, 2, 0, 0]'),
#  Text(0.0049261083743842365, 0.625, 'gini = 0.0\nsamples = 19\nvalue = [0, 32, 0, 0, 0]'),
#  Text(0.014778325123152709, 0.625, 'x[6] <= 12.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0]'),
#  Text(0.009852216748768473, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.019704433497536946, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.019704433497536946, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.024630541871921183, 0.725, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.11145320197044335, 0.775, 'x[5] <= 6.5\ngini = 0.497\nsamples = 102\nvalue = [5, 27, 111, 17, 3]'),
#  Text(0.05788177339901478, 0.725, 'x[6] <= 13.0\ngini = 0.731\nsamples = 26\nvalue = [4, 8, 15, 11, 2]'),
#  Text(0.05295566502463054, 0.675, 'x[2] <= 0.12\ngini = 0.753\nsamples = 21\nvalue = [4, 8, 8, 11, 2]'),
#  Text(0.034482758620689655, 0.625, 'x[8] <= 3.635\ngini = 0.37\nsamples = 5\nvalue = [1, 7, 0, 1, 0]'),
#  Text(0.029556650246305417, 0.575, 'x[9] <= 0.44\ngini = 0.219\nsamples = 4\nvalue = [1, 7, 0, 0, 0]'),
#  Text(0.024630541871921183, 0.525, 'x[2] <= 0.04\ngini = 0.375\nsamples = 2\nvalue = [1, 3, 0, 0, 0]'),
#  Text(0.019704433497536946, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.029556650246305417, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.034482758620689655, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.03940886699507389, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.07142857142857142, 0.625, 'x[4] <= 0.074\ngini = 0.691\nsamples = 16\nvalue = [3, 1, 8, 10, 2]'),
#  Text(0.054187192118226604, 0.575, 'x[6] <= 10.5\ngini = 0.596\nsamples = 10\nvalue = [2, 1, 1, 9, 2]'),
#  Text(0.04433497536945813, 0.525, 'x[1] <= 0.38\ngini = 0.298\nsamples = 7\nvalue = [2, 0, 0, 9, 0]'),
#  Text(0.03940886699507389, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 9, 0]'),
#  Text(0.04926108374384237, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.06403940886699508, 0.525, 'x[1] <= 0.375\ngini = 0.625\nsamples = 3\nvalue = [0, 1, 1, 0, 2]'),
#  Text(0.059113300492610835, 0.475, 'x[2] <= 0.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.054187192118226604, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.06403940886699508, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.06896551724137931, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.08866995073891626, 0.575, 'x[2] <= 0.45\ngini = 0.37\nsamples = 6\nvalue = [1, 0, 7, 1, 0]'),
#  Text(0.08374384236453201, 0.525, 'x[5] <= 3.5\ngini = 0.219\nsamples = 5\nvalue = [1, 0, 7, 0, 0]'),
#  Text(0.07881773399014778, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.08866995073891626, 0.475, 'x[1] <= 0.41\ngini = 0.444\nsamples = 2\nvalue = [1, 0, 2, 0, 0]'),
#  Text(0.08374384236453201, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.09359605911330049, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.09359605911330049, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.06280788177339902, 0.675, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 7, 0, 0]'),
#  Text(0.16502463054187191, 0.725, 'x[3] <= 3.675\ngini = 0.364\nsamples = 76\nvalue = [1, 19, 96, 6, 1]'),
#  Text(0.16009852216748768, 0.675, 'x[0] <= 8.4\ngini = 0.331\nsamples = 75\nvalue = [1, 15, 96, 6, 1]'),
#  Text(0.1330049261083744, 0.625, 'x[5] <= 33.5\ngini = 0.27\nsamples = 66\nvalue = [1, 12, 88, 3, 0]'),
#  Text(0.12807881773399016, 0.575, 'x[9] <= 0.45\ngini = 0.245\nsamples = 64\nvalue = [1, 10, 88, 3, 0]'),
#  Text(0.12315270935960591, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.1330049261083744, 0.525, 'x[6] <= 59.5\ngini = 0.218\nsamples = 63\nvalue = [1, 8, 88, 3, 0]'),
#  Text(0.11330049261083744, 0.475, 'x[6] <= 15.5\ngini = 0.148\nsamples = 53\nvalue = [1, 4, 82, 2, 0]'),
#  Text(0.10344827586206896, 0.425, 'x[4] <= 0.079\ngini = 0.408\nsamples = 4\nvalue = [0, 0, 5, 2, 0]'),
#  Text(0.09852216748768473, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.10837438423645321, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.12315270935960591, 0.425, 'x[7] <= 0.994\ngini = 0.116\nsamples = 49\nvalue = [1, 4, 77, 0, 0]'),
#  Text(0.11822660098522167, 0.375, 'x[10] <= 11.4\ngini = 0.287\nsamples = 19\nvalue = [1, 4, 25, 0, 0]'),
#  Text(0.10837438423645321, 0.325, 'x[2] <= 0.04\ngini = 0.56\nsamples = 4\nvalue = [1, 3, 1, 0, 0]'),
#  Text(0.10344827586206896, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.11330049261083744, 0.275, 'x[4] <= 0.075\ngini = 0.375\nsamples = 3\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.10837438423645321, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.11822660098522167, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.12807881773399016, 0.325, 'x[1] <= 0.768\ngini = 0.077\nsamples = 15\nvalue = [0, 1, 24, 0, 0]'),
#  Text(0.12315270935960591, 0.275, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 24, 0, 0]'),
#  Text(0.1330049261083744, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.12807881773399016, 0.375, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 52, 0, 0]'),
#  Text(0.15270935960591134, 0.475, 'x[1] <= 0.485\ngini = 0.562\nsamples = 10\nvalue = [0, 4, 6, 1, 0]'),
#  Text(0.14285714285714285, 0.425, 'x[10] <= 11.7\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1, 0]'),
#  Text(0.13793103448275862, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.1477832512315271, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.1625615763546798, 0.425, 'x[0] <= 5.1\ngini = 0.245\nsamples = 6\nvalue = [0, 1, 6, 0, 0]'),
#  Text(0.15763546798029557, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.16748768472906403, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 6, 0, 0]'),
#  Text(0.13793103448275862, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.18719211822660098, 0.625, 'x[4] <= 0.068\ngini = 0.631\nsamples = 9\nvalue = [0, 3, 8, 3, 1]'),
#  Text(0.17733990147783252, 0.575, 'x[1] <= 0.295\ngini = 0.612\nsamples = 5\nvalue = [0, 3, 1, 3, 0]'),
#  Text(0.1724137931034483, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.18226600985221675, 0.525, 'x[7] <= 0.995\ngini = 0.375\nsamples = 3\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.17733990147783252, 0.475, 'x[9] <= 0.575\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.1724137931034483, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.18226600985221675, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.18719211822660098, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.19704433497536947, 0.575, 'x[6] <= 18.5\ngini = 0.219\nsamples = 4\nvalue = [0, 0, 7, 0, 1]'),
#  Text(0.1921182266009852, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.2019704433497537, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 7, 0, 0]'),
#  Text(0.16995073891625614, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.1748768472906404, 0.825, 'x[3] <= 1.85\ngini = 0.654\nsamples = 8\nvalue = [0, 6, 5, 8, 0]'),
#  Text(0.16995073891625614, 0.775, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 8, 0]'),
#  Text(0.17980295566502463, 0.775, 'x[8] <= 3.315\ngini = 0.496\nsamples = 6\nvalue = [0, 6, 5, 0, 0]'),
#  Text(0.1748768472906404, 0.725, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.18472906403940886, 0.725, 'x[3] <= 2.4\ngini = 0.375\nsamples = 4\nvalue = [0, 6, 2, 0, 0]'),
#  Text(0.17980295566502463, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 6, 0, 0, 0]'),
#  Text(0.1896551724137931, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.22660098522167488, 0.875, 'x[1] <= 0.325\ngini = 0.541\nsamples = 54\nvalue = [0, 5, 38, 50, 0]'),
#  Text(0.22167487684729065, 0.825, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 21, 0]'),
#  Text(0.2315270935960591, 0.825, 'x[10] <= 12.45\ngini = 0.554\nsamples = 42\nvalue = [0, 5, 38, 29, 0]'),
#  Text(0.22660098522167488, 0.775, 'x[7] <= 0.995\ngini = 0.467\nsamples = 33\nvalue = [0, 5, 38, 12, 0]'),
#  Text(0.21182266009852216, 0.725, 'x[5] <= 19.5\ngini = 0.174\nsamples = 18\nvalue = [0, 1, 29, 2, 0]'),
#  Text(0.20689655172413793, 0.675, 'x[8] <= 3.26\ngini = 0.403\nsamples = 9\nvalue = [0, 1, 9, 2, 0]'),
#  Text(0.2019704433497537, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.21182266009852216, 0.625, 'x[6] <= 56.5\ngini = 0.18\nsamples = 8\nvalue = [0, 1, 9, 0, 0]'),
#  Text(0.20689655172413793, 0.575, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 9, 0, 0]'),
#  Text(0.21674876847290642, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.21674876847290642, 0.675, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 20, 0, 0]'),
#  Text(0.2413793103448276, 0.725, 'x[2] <= 0.445\ngini = 0.628\nsamples = 15\nvalue = [0, 4, 9, 10, 0]'),
#  Text(0.23645320197044334, 0.675, 'x[7] <= 0.995\ngini = 0.632\nsamples = 12\nvalue = [0, 4, 9, 6, 0]'),
#  Text(0.2315270935960591, 0.625, 'x[10] <= 11.25\ngini = 0.48\nsamples = 7\nvalue = [0, 4, 0, 6, 0]'),
#  Text(0.22660098522167488, 0.575, 'gini = 0.0\nsamples = 3\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.23645320197044334, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0]'),
#  Text(0.2413793103448276, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 9, 0, 0]'),
#  Text(0.24630541871921183, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 4, 0]'),
#  Text(0.23645320197044334, 0.775, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 17, 0]'),
#  Text(0.6389605141625616, 0.925, 'x[1] <= 0.548\ngini = 0.594\nsamples = 528\nvalue = [21, 414, 341, 58, 14]'),
#  Text(0.44598599137931033, 0.875, 'x[5] <= 14.5\ngini = 0.626\nsamples = 283\nvalue = [9, 161, 221, 52, 13]'),
#  Text(0.35995227832512317, 0.825, 'x[7] <= 1.001\ngini = 0.614\nsamples = 163\nvalue = [4, 65, 141, 39, 9]'),
#  Text(0.3255080049261084, 0.775, 'x[4] <= 0.084\ngini = 0.607\nsamples = 161\nvalue = [4, 65, 140, 35, 9]'),
#  Text(0.27139778325123154, 0.725, 'x[5] <= 3.5\ngini = 0.525\nsamples = 102\nvalue = [3, 33, 105, 11, 9]'),
#  Text(0.2561576354679803, 0.675, 'x[6] <= 14.5\ngini = 0.625\nsamples = 8\nvalue = [0, 6, 3, 3, 0]'),
#  Text(0.2512315270935961, 0.625, 'x[6] <= 9.5\ngini = 0.656\nsamples = 5\nvalue = [0, 2, 3, 3, 0]'),
#  Text(0.24630541871921183, 0.575, 'x[10] <= 11.3\ngini = 0.48\nsamples = 3\nvalue = [0, 2, 0, 3, 0]'),
#  Text(0.2413793103448276, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.2512315270935961, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.2561576354679803, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.26108374384236455, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.28663793103448276, 0.675, 'x[10] <= 12.55\ngini = 0.492\nsamples = 94\nvalue = [3, 27, 102, 8, 9]'),
#  Text(0.28171182266009853, 0.625, 'x[9] <= 0.475\ngini = 0.466\nsamples = 93\nvalue = [3, 27, 102, 8, 5]'),
#  Text(0.2660098522167488, 0.575, 'x[2] <= 0.205\ngini = 0.408\nsamples = 5\nvalue = [2, 5, 0, 0, 0]'),
#  Text(0.26108374384236455, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.270935960591133, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.2974137931034483, 0.575, 'x[1] <= 0.25\ngini = 0.424\nsamples = 88\nvalue = [1, 22, 102, 8, 5]'),
#  Text(0.28078817733990147, 0.525, 'x[8] <= 3.145\ngini = 0.716\nsamples = 6\nvalue = [1, 3, 3, 2, 0]'),
#  Text(0.27586206896551724, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.2857142857142857, 0.475, 'x[2] <= 0.475\ngini = 0.611\nsamples = 5\nvalue = [1, 0, 3, 2, 0]'),
#  Text(0.28078817733990147, 0.425, 'x[2] <= 0.395\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0]'),
#  Text(0.27586206896551724, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.2857142857142857, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.29064039408866993, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.31403940886699505, 0.525, 'x[10] <= 9.45\ngini = 0.386\nsamples = 82\nvalue = [0, 19, 99, 6, 5]'),
#  Text(0.3091133004926108, 0.475, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 22, 0, 0]'),
#  Text(0.31896551724137934, 0.475, 'x[0] <= 7.15\ngini = 0.445\nsamples = 69\nvalue = [0, 19, 77, 6, 5]'),
#  Text(0.30049261083743845, 0.425, 'x[2] <= 0.05\ngini = 0.49\nsamples = 4\nvalue = [0, 4, 3, 0, 0]'),
#  Text(0.2955665024630542, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.3054187192118227, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.3374384236453202, 0.425, 'x[6] <= 30.5\ngini = 0.424\nsamples = 65\nvalue = [0, 15, 74, 6, 5]'),
#  Text(0.31527093596059114, 0.375, 'x[9] <= 1.05\ngini = 0.369\nsamples = 51\nvalue = [0, 6, 62, 6, 5]'),
#  Text(0.3103448275862069, 0.325, 'x[0] <= 10.65\ngini = 0.354\nsamples = 50\nvalue = [0, 6, 62, 5, 5]'),
#  Text(0.29064039408866993, 0.275, 'x[1] <= 0.385\ngini = 0.218\nsamples = 38\nvalue = [0, 2, 51, 5, 0]'),
#  Text(0.270935960591133, 0.225, 'x[4] <= 0.082\ngini = 0.395\nsamples = 15\nvalue = [0, 1, 15, 4, 0]'),
#  Text(0.2660098522167488, 0.175, 'x[8] <= 3.25\ngini = 0.349\nsamples = 14\nvalue = [0, 1, 15, 3, 0]'),
#  Text(0.2561576354679803, 0.125, 'x[3] <= 2.0\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0]'),
#  Text(0.2512315270935961, 0.075, 'x[7] <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0]'),
#  Text(0.24630541871921183, 0.025, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.2561576354679803, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.26108374384236455, 0.075, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.27586206896551724, 0.125, 'x[9] <= 0.795\ngini = 0.142\nsamples = 8\nvalue = [0, 1, 12, 0, 0]'),
#  Text(0.270935960591133, 0.075, 'x[8] <= 3.295\ngini = 0.32\nsamples = 4\nvalue = [0, 1, 4, 0, 0]'),
#  Text(0.2660098522167488, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.27586206896551724, 0.025, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.28078817733990147, 0.075, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 8, 0, 0]'),
#  Text(0.27586206896551724, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3103448275862069, 0.225, 'x[2] <= 0.545\ngini = 0.101\nsamples = 23\nvalue = [0, 1, 36, 1, 0]'),
#  Text(0.30049261083743845, 0.175, 'x[7] <= 0.996\ngini = 0.054\nsamples = 21\nvalue = [0, 0, 35, 1, 0]'),
#  Text(0.2955665024630542, 0.125, 'x[0] <= 8.5\ngini = 0.142\nsamples = 8\nvalue = [0, 0, 12, 1, 0]'),
#  Text(0.29064039408866993, 0.075, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 9, 0, 0]'),
#  Text(0.30049261083743845, 0.075, 'x[5] <= 11.5\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3, 1, 0]'),
#  Text(0.2955665024630542, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3054187192118227, 0.025, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.3054187192118227, 0.125, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 23, 0, 0]'),
#  Text(0.32019704433497537, 0.175, 'x[3] <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.31527093596059114, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.3251231527093596, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.33004926108374383, 0.275, 'x[5] <= 5.5\ngini = 0.595\nsamples = 12\nvalue = [0, 4, 11, 0, 5]'),
#  Text(0.3251231527093596, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.33497536945812806, 0.225, 'x[6] <= 17.0\ngini = 0.461\nsamples = 10\nvalue = [0, 4, 11, 0, 1]'),
#  Text(0.33004926108374383, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.3399014778325123, 0.175, 'x[9] <= 0.55\ngini = 0.357\nsamples = 8\nvalue = [0, 2, 11, 0, 1]'),
#  Text(0.33497536945812806, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.3448275862068966, 0.125, 'x[6] <= 28.0\ngini = 0.153\nsamples = 7\nvalue = [0, 0, 11, 0, 1]'),
#  Text(0.3399014778325123, 0.075, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 11, 0, 0]'),
#  Text(0.3497536945812808, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.32019704433497537, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.35960591133004927, 0.375, 'x[9] <= 0.655\ngini = 0.49\nsamples = 14\nvalue = [0, 9, 12, 0, 0]'),
#  Text(0.35467980295566504, 0.325, 'x[1] <= 0.51\ngini = 0.459\nsamples = 10\nvalue = [0, 9, 5, 0, 0]'),
#  Text(0.3497536945812808, 0.275, 'x[1] <= 0.365\ngini = 0.5\nsamples = 8\nvalue = [0, 5, 5, 0, 0]'),
#  Text(0.3448275862068966, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.35467980295566504, 0.225, 'x[7] <= 0.996\ngini = 0.469\nsamples = 6\nvalue = [0, 3, 5, 0, 0]'),
#  Text(0.3497536945812808, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.35960591133004927, 0.175, 'x[4] <= 0.081\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.35467980295566504, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.3645320197044335, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.35960591133004927, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.3645320197044335, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0]'),
#  Text(0.291564039408867, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.3796182266009852, 0.725, 'x[9] <= 0.555\ngini = 0.666\nsamples = 59\nvalue = [1, 32, 35, 24, 0]'),
#  Text(0.35714285714285715, 0.675, 'x[6] <= 13.0\ngini = 0.117\nsamples = 9\nvalue = [0, 15, 1, 0, 0]'),
#  Text(0.3522167487684729, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.3620689655172414, 0.625, 'gini = 0.0\nsamples = 8\nvalue = [0, 15, 0, 0, 0]'),
#  Text(0.4020935960591133, 0.675, 'x[10] <= 10.35\ngini = 0.65\nsamples = 50\nvalue = [1, 17, 34, 24, 0]'),
#  Text(0.37192118226600984, 0.625, 'x[4] <= 0.168\ngini = 0.554\nsamples = 21\nvalue = [0, 11, 15, 2, 0]'),
#  Text(0.3669950738916256, 0.575, 'x[7] <= 0.997\ngini = 0.571\nsamples = 17\nvalue = [0, 11, 8, 2, 0]'),
#  Text(0.35714285714285715, 0.525, 'x[10] <= 9.85\ngini = 0.406\nsamples = 4\nvalue = [0, 6, 1, 1, 0]'),
#  Text(0.3522167487684729, 0.475, 'x[4] <= 0.099\ngini = 0.245\nsamples = 3\nvalue = [0, 6, 0, 1, 0]'),
#  Text(0.3472906403940887, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.35714285714285715, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 6, 0, 0, 0]'),
#  Text(0.3620689655172414, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.3768472906403941, 0.525, 'x[3] <= 1.9\ngini = 0.556\nsamples = 13\nvalue = [0, 5, 7, 1, 0]'),
#  Text(0.37192118226600984, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.3817733990147783, 0.475, 'x[6] <= 43.5\ngini = 0.568\nsamples = 9\nvalue = [0, 5, 3, 1, 0]'),
#  Text(0.3768472906403941, 0.425, 'x[9] <= 0.605\ngini = 0.469\nsamples = 8\nvalue = [0, 5, 3, 0, 0]'),
#  Text(0.37192118226600984, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.3817733990147783, 0.375, 'x[5] <= 5.0\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0, 0]'),
#  Text(0.3768472906403941, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.3866995073891626, 0.325, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.3866995073891626, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.3768472906403941, 0.575, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0]'),
#  Text(0.43226600985221675, 0.625, 'x[2] <= 0.58\ngini = 0.617\nsamples = 29\nvalue = [1, 6, 19, 22, 0]'),
#  Text(0.41379310344827586, 0.575, 'x[3] <= 2.35\ngini = 0.526\nsamples = 18\nvalue = [1, 1, 17, 9, 0]'),
#  Text(0.39655172413793105, 0.525, 'x[4] <= 0.104\ngini = 0.142\nsamples = 7\nvalue = [0, 1, 12, 0, 0]'),
#  Text(0.3916256157635468, 0.475, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 10, 0, 0]'),
#  Text(0.4014778325123153, 0.475, 'x[2] <= 0.485\ngini = 0.444\nsamples = 2\nvalue = [0, 1, 2, 0, 0]'),
#  Text(0.39655172413793105, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.4064039408866995, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.43103448275862066, 0.525, 'x[4] <= 0.113\ngini = 0.524\nsamples = 11\nvalue = [1, 0, 5, 9, 0]'),
#  Text(0.4211822660098522, 0.475, 'x[9] <= 0.86\ngini = 0.298\nsamples = 9\nvalue = [0, 0, 2, 9, 0]'),
#  Text(0.41625615763546797, 0.425, 'x[2] <= 0.48\ngini = 0.18\nsamples = 8\nvalue = [0, 0, 1, 9, 0]'),
#  Text(0.41133004926108374, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 7, 0]'),
#  Text(0.4211822660098522, 0.375, 'x[6] <= 22.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0]'),
#  Text(0.41625615763546797, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.42610837438423643, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.42610837438423643, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.4408866995073892, 0.475, 'x[0] <= 8.65\ngini = 0.375\nsamples = 2\nvalue = [1, 0, 3, 0, 0]'),
#  Text(0.43596059113300495, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.4458128078817734, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.45073891625615764, 0.575, 'x[8] <= 3.21\ngini = 0.505\nsamples = 11\nvalue = [0, 5, 2, 13, 0]'),
#  Text(0.4458128078817734, 0.525, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 13, 0]'),
#  Text(0.45566502463054187, 0.525, 'x[6] <= 31.5\ngini = 0.408\nsamples = 5\nvalue = [0, 5, 2, 0, 0]'),
#  Text(0.45073891625615764, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.4605911330049261, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.39439655172413796, 0.775, 'x[1] <= 0.41\ngini = 0.32\nsamples = 2\nvalue = [0, 0, 1, 4, 0]'),
#  Text(0.38947044334975367, 0.725, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 4, 0]'),
#  Text(0.3993226600985222, 0.725, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.5320197044334976, 0.825, 'x[10] <= 9.45\ngini = 0.596\nsamples = 120\nvalue = [5, 96, 80, 13, 4]'),
#  Text(0.4729064039408867, 0.775, 'x[9] <= 0.705\ngini = 0.153\nsamples = 24\nvalue = [0, 33, 3, 0, 0]'),
#  Text(0.46798029556650245, 0.725, 'gini = 0.0\nsamples = 19\nvalue = [0, 30, 0, 0, 0]'),
#  Text(0.47783251231527096, 0.725, 'x[6] <= 53.5\ngini = 0.5\nsamples = 5\nvalue = [0, 3, 3, 0, 0]'),
#  Text(0.4729064039408867, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.4827586206896552, 0.675, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.5911330049261084, 0.775, 'x[8] <= 3.45\ngini = 0.615\nsamples = 96\nvalue = [5, 63, 77, 13, 4]'),
#  Text(0.5443349753694581, 0.725, 'x[0] <= 7.55\ngini = 0.633\nsamples = 84\nvalue = [5, 60, 59, 13, 4]'),
#  Text(0.49261083743842365, 0.675, 'x[1] <= 0.425\ngini = 0.389\nsamples = 21\nvalue = [2, 26, 5, 1, 0]'),
#  Text(0.4802955665024631, 0.625, 'x[3] <= 2.15\ngini = 0.615\nsamples = 11\nvalue = [2, 6, 5, 0, 0]'),
#  Text(0.47044334975369456, 0.575, 'x[5] <= 29.5\ngini = 0.5\nsamples = 3\nvalue = [2, 0, 2, 0, 0]'),
#  Text(0.46551724137931033, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.4753694581280788, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.49014778325123154, 0.575, 'x[8] <= 3.385\ngini = 0.444\nsamples = 8\nvalue = [0, 6, 3, 0, 0]'),
#  Text(0.4852216748768473, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.49507389162561577, 0.525, 'x[3] <= 2.35\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3, 0, 0]'),
#  Text(0.49014778325123154, 0.475, 'x[8] <= 3.415\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0]'),
#  Text(0.4852216748768473, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.49507389162561577, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.5, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.5049261083743842, 0.625, 'x[5] <= 29.5\ngini = 0.091\nsamples = 10\nvalue = [0, 20, 0, 1, 0]'),
#  Text(0.5, 0.575, 'gini = 0.0\nsamples = 8\nvalue = [0, 17, 0, 0, 0]'),
#  Text(0.5098522167487685, 0.575, 'x[9] <= 0.635\ngini = 0.375\nsamples = 2\nvalue = [0, 3, 0, 1, 0]'),
#  Text(0.5049261083743842, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.5147783251231527, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.5960591133004927, 0.675, 'x[5] <= 30.0\ngini = 0.63\nsamples = 63\nvalue = [3, 34, 54, 12, 4]'),
#  Text(0.5640394088669951, 0.625, 'x[8] <= 3.305\ngini = 0.585\nsamples = 55\nvalue = [1, 27, 52, 8, 4]'),
#  Text(0.5394088669950738, 0.575, 'x[6] <= 81.5\ngini = 0.609\nsamples = 35\nvalue = [1, 24, 22, 6, 0]'),
#  Text(0.5344827586206896, 0.525, 'x[9] <= 0.63\ngini = 0.604\nsamples = 28\nvalue = [1, 12, 22, 6, 0]'),
#  Text(0.5147783251231527, 0.475, 'x[6] <= 59.5\ngini = 0.486\nsamples = 9\nvalue = [1, 8, 3, 0, 0]'),
#  Text(0.5049261083743842, 0.425, 'x[5] <= 23.0\ngini = 0.219\nsamples = 6\nvalue = [1, 7, 0, 0, 0]'),
#  Text(0.5, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 7, 0, 0, 0]'),
#  Text(0.5098522167487685, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.5246305418719212, 0.425, 'x[4] <= 0.077\ngini = 0.375\nsamples = 3\nvalue = [0, 1, 3, 0, 0]'),
#  Text(0.5197044334975369, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.5295566502463054, 0.375, 'x[5] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.5246305418719212, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.5344827586206896, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.5541871921182266, 0.475, 'x[3] <= 1.55\ngini = 0.509\nsamples = 19\nvalue = [0, 4, 19, 6, 0]'),
#  Text(0.5492610837438424, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0]'),
#  Text(0.5591133004926109, 0.425, 'x[4] <= 0.093\ngini = 0.39\nsamples = 17\nvalue = [0, 4, 19, 2, 0]'),
#  Text(0.5492610837438424, 0.375, 'x[2] <= 0.51\ngini = 0.117\nsamples = 12\nvalue = [0, 1, 15, 0, 0]'),
#  Text(0.5443349753694581, 0.325, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 12, 0, 0]'),
#  Text(0.5541871921182266, 0.325, 'x[7] <= 1.0\ngini = 0.375\nsamples = 3\nvalue = [0, 1, 3, 0, 0]'),
#  Text(0.5492610837438424, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.5591133004926109, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.5689655172413793, 0.375, 'x[2] <= 0.405\ngini = 0.642\nsamples = 5\nvalue = [0, 3, 4, 2, 0]'),
#  Text(0.5640394088669951, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.5738916256157636, 0.325, 'x[1] <= 0.355\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 4, 2, 0]'),
#  Text(0.5689655172413793, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.5788177339901478, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.5443349753694581, 0.525, 'gini = 0.0\nsamples = 7\nvalue = [0, 12, 0, 0, 0]'),
#  Text(0.5886699507389163, 0.575, 'x[5] <= 15.5\ngini = 0.389\nsamples = 20\nvalue = [0, 3, 30, 2, 4]'),
#  Text(0.583743842364532, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.5935960591133005, 0.525, 'x[6] <= 64.5\ngini = 0.255\nsamples = 19\nvalue = [0, 3, 30, 2, 0]'),
#  Text(0.5788177339901478, 0.475, 'x[4] <= 0.091\ngini = 0.137\nsamples = 15\nvalue = [0, 0, 25, 2, 0]'),
#  Text(0.5738916256157636, 0.425, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 23, 0, 0]'),
#  Text(0.583743842364532, 0.425, 'x[5] <= 22.0\ngini = 0.5\nsamples = 3\nvalue = [0, 0, 2, 2, 0]'),
#  Text(0.5788177339901478, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.5886699507389163, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.6083743842364532, 0.475, 'x[2] <= 0.4\ngini = 0.469\nsamples = 4\nvalue = [0, 3, 5, 0, 0]'),
#  Text(0.603448275862069, 0.425, 'x[1] <= 0.445\ngini = 0.278\nsamples = 3\nvalue = [0, 1, 5, 0, 0]'),
#  Text(0.5985221674876847, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.6083743842364532, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.6133004926108374, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.6280788177339901, 0.625, 'x[2] <= 0.36\ngini = 0.676\nsamples = 8\nvalue = [2, 7, 2, 4, 0]'),
#  Text(0.6231527093596059, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 3, 0]'),
#  Text(0.6330049261083743, 0.575, 'x[6] <= 60.0\ngini = 0.597\nsamples = 7\nvalue = [2, 7, 2, 1, 0]'),
#  Text(0.6231527093596059, 0.525, 'x[1] <= 0.435\ngini = 0.5\nsamples = 2\nvalue = [2, 0, 2, 0, 0]'),
#  Text(0.6182266009852216, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.6280788177339901, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.6428571428571429, 0.525, 'x[3] <= 4.575\ngini = 0.219\nsamples = 5\nvalue = [0, 7, 0, 1, 0]'),
#  Text(0.6379310344827587, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 7, 0, 0, 0]'),
#  Text(0.6477832512315271, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.6379310344827587, 0.725, 'x[2] <= 0.19\ngini = 0.245\nsamples = 12\nvalue = [0, 3, 18, 0, 0]'),
#  Text(0.6330049261083743, 0.675, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.6428571428571429, 0.675, 'x[3] <= 2.6\ngini = 0.1\nsamples = 10\nvalue = [0, 1, 18, 0, 0]'),
#  Text(0.6379310344827587, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 18, 0, 0]'),
#  Text(0.6477832512315271, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8319350369458128, 0.875, 'x[10] <= 10.35\ngini = 0.489\nsamples = 245\nvalue = [12, 253, 120, 6, 1]'),
#  Text(0.7020474137931034, 0.825, 'x[10] <= 9.05\ngini = 0.424\nsamples = 198\nvalue = [8, 227, 77, 4, 0]'),
#  Text(0.6527093596059114, 0.775, 'x[7] <= 0.997\ngini = 0.124\nsamples = 7\nvalue = [0, 1, 14, 0, 0]'),
#  Text(0.6477832512315271, 0.725, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 9, 0, 0]'),
#  Text(0.6576354679802956, 0.725, 'x[2] <= 0.16\ngini = 0.278\nsamples = 2\nvalue = [0, 1, 5, 0, 0]'),
#  Text(0.6527093596059114, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.6625615763546798, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.7513854679802956, 0.775, 'x[9] <= 0.535\ngini = 0.392\nsamples = 191\nvalue = [8, 226, 63, 4, 0]'),
#  Text(0.6822660098522167, 0.725, 'x[7] <= 0.997\ngini = 0.211\nsamples = 52\nvalue = [2, 68, 7, 0, 0]'),
#  Text(0.6724137931034483, 0.675, 'x[0] <= 7.95\ngini = 0.035\nsamples = 36\nvalue = [0, 55, 1, 0, 0]'),
#  Text(0.6674876847290641, 0.625, 'gini = 0.0\nsamples = 23\nvalue = [0, 38, 0, 0, 0]'),
#  Text(0.6773399014778325, 0.625, 'x[0] <= 8.05\ngini = 0.105\nsamples = 13\nvalue = [0, 17, 1, 0, 0]'),
#  Text(0.6724137931034483, 0.575, 'x[6] <= 79.5\ngini = 0.375\nsamples = 3\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.6674876847290641, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.6773399014778325, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.6822660098522167, 0.575, 'gini = 0.0\nsamples = 10\nvalue = [0, 14, 0, 0, 0]'),
#  Text(0.6921182266009852, 0.675, 'x[6] <= 40.5\ngini = 0.526\nsamples = 16\nvalue = [2, 13, 6, 0, 0]'),
#  Text(0.687192118226601, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [0, 10, 0, 0, 0]'),
#  Text(0.6970443349753694, 0.625, 'x[5] <= 13.0\ngini = 0.595\nsamples = 9\nvalue = [2, 3, 6, 0, 0]'),
#  Text(0.6921182266009852, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.7019704433497537, 0.575, 'x[6] <= 73.0\ngini = 0.54\nsamples = 8\nvalue = [1, 3, 6, 0, 0]'),
#  Text(0.6921182266009852, 0.525, 'x[2] <= 0.245\ngini = 0.278\nsamples = 4\nvalue = [1, 0, 5, 0, 0]'),
#  Text(0.687192118226601, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.6970443349753694, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.7118226600985221, 0.525, 'x[3] <= 2.45\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1, 0, 0]'),
#  Text(0.7068965517241379, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.7167487684729064, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.8205049261083743, 0.725, 'x[0] <= 7.75\ngini = 0.439\nsamples = 139\nvalue = [6, 158, 56, 4, 0]'),
#  Text(0.7727832512315271, 0.675, 'x[3] <= 1.45\ngini = 0.326\nsamples = 62\nvalue = [3, 76, 13, 2, 0]'),
#  Text(0.7678571428571429, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.7777093596059114, 0.625, 'x[2] <= 0.485\ngini = 0.312\nsamples = 61\nvalue = [2, 76, 13, 2, 0]'),
#  Text(0.7727832512315271, 0.575, 'x[1] <= 0.635\ngini = 0.282\nsamples = 60\nvalue = [0, 76, 13, 2, 0]'),
#  Text(0.7401477832512315, 0.525, 'x[9] <= 0.585\ngini = 0.38\nsamples = 27\nvalue = [0, 31, 9, 1, 0]'),
#  Text(0.7266009852216748, 0.475, 'x[9] <= 0.555\ngini = 0.5\nsamples = 7\nvalue = [0, 6, 6, 0, 0]'),
#  Text(0.7216748768472906, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 6, 0, 0, 0]'),
#  Text(0.7315270935960592, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 6, 0, 0]'),
#  Text(0.7536945812807881, 0.475, 'x[9] <= 0.695\ngini = 0.245\nsamples = 20\nvalue = [0, 25, 3, 1, 0]'),
#  Text(0.7413793103448276, 0.425, 'x[4] <= 0.11\ngini = 0.145\nsamples = 17\nvalue = [0, 24, 1, 1, 0]'),
#  Text(0.7315270935960592, 0.375, 'x[8] <= 3.5\ngini = 0.08\nsamples = 15\nvalue = [0, 23, 0, 1, 0]'),
#  Text(0.7266009852216748, 0.325, 'gini = 0.0\nsamples = 14\nvalue = [0, 23, 0, 0, 0]'),
#  Text(0.7364532019704434, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.7512315270935961, 0.375, 'x[2] <= 0.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.7463054187192119, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.7561576354679803, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.7660098522167488, 0.425, 'x[5] <= 17.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0]'),
#  Text(0.7610837438423645, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.770935960591133, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8054187192118226, 0.525, 'x[8] <= 3.505\ngini = 0.183\nsamples = 33\nvalue = [0, 45, 4, 1, 0]'),
#  Text(0.8004926108374384, 0.475, 'x[9] <= 0.64\ngini = 0.271\nsamples = 23\nvalue = [0, 27, 4, 1, 0]'),
#  Text(0.7857142857142857, 0.425, 'x[4] <= 0.095\ngini = 0.153\nsamples = 16\nvalue = [0, 22, 2, 0, 0]'),
#  Text(0.7807881773399015, 0.375, 'gini = 0.0\nsamples = 10\nvalue = [0, 17, 0, 0, 0]'),
#  Text(0.7906403940886699, 0.375, 'x[10] <= 9.35\ngini = 0.408\nsamples = 6\nvalue = [0, 5, 2, 0, 0]'),
#  Text(0.7857142857142857, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.7955665024630542, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.8152709359605911, 0.425, 'x[8] <= 3.465\ngini = 0.531\nsamples = 7\nvalue = [0, 5, 2, 1, 0]'),
#  Text(0.8103448275862069, 0.375, 'x[4] <= 0.134\ngini = 0.278\nsamples = 5\nvalue = [0, 5, 0, 1, 0]'),
#  Text(0.8054187192118226, 0.325, 'gini = 0.0\nsamples = 4\nvalue = [0, 5, 0, 0, 0]'),
#  Text(0.8152709359605911, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.8201970443349754, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.8103448275862069, 0.475, 'gini = 0.0\nsamples = 10\nvalue = [0, 18, 0, 0, 0]'),
#  Text(0.7826354679802956, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.8682266009852216, 0.675, 'x[0] <= 8.05\ngini = 0.492\nsamples = 77\nvalue = [3, 82, 43, 2, 0]'),
#  Text(0.8497536945812808, 0.625, 'x[6] <= 95.0\ngini = 0.524\nsamples = 14\nvalue = [0, 11, 15, 1, 0]'),
#  Text(0.8399014778325123, 0.575, 'x[7] <= 0.997\ngini = 0.398\nsamples = 10\nvalue = [0, 3, 12, 1, 0]'),
#  Text(0.8349753694581281, 0.525, 'x[4] <= 0.074\ngini = 0.142\nsamples = 8\nvalue = [0, 0, 12, 1, 0]'),
#  Text(0.8300492610837439, 0.475, 'x[6] <= 17.5\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0]'),
#  Text(0.8251231527093597, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.8349753694581281, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.8399014778325123, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 10, 0, 0]'),
#  Text(0.8448275862068966, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.8596059113300493, 0.575, 'x[4] <= 0.069\ngini = 0.397\nsamples = 4\nvalue = [0, 8, 3, 0, 0]'),
#  Text(0.854679802955665, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.8645320197044335, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [0, 8, 0, 0, 0]'),
#  Text(0.8866995073891626, 0.625, 'x[4] <= 0.076\ngini = 0.45\nsamples = 63\nvalue = [3, 71, 28, 1, 0]'),
#  Text(0.8817733990147784, 0.575, 'gini = 0.0\nsamples = 8\nvalue = [0, 13, 0, 0, 0]'),
#  Text(0.8916256157635468, 0.575, 'x[5] <= 8.5\ngini = 0.487\nsamples = 55\nvalue = [3, 58, 28, 1, 0]'),
#  Text(0.874384236453202, 0.525, 'x[10] <= 10.15\ngini = 0.515\nsamples = 10\nvalue = [0, 7, 12, 1, 0]'),
#  Text(0.8694581280788177, 0.475, 'x[1] <= 0.635\ngini = 0.443\nsamples = 8\nvalue = [0, 4, 12, 1, 0]'),
#  Text(0.8645320197044335, 0.425, 'x[7] <= 0.998\ngini = 0.594\nsamples = 4\nvalue = [0, 4, 3, 1, 0]'),
#  Text(0.8596059113300493, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.8694581280788177, 0.375, 'x[2] <= 0.395\ngini = 0.375\nsamples = 2\nvalue = [0, 0, 3, 1, 0]'),
#  Text(0.8645320197044335, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.874384236453202, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.874384236453202, 0.425, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 9, 0, 0]'),
#  Text(0.8793103448275862, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.9088669950738916, 0.525, 'x[0] <= 9.95\ngini = 0.415\nsamples = 45\nvalue = [3, 51, 16, 0, 0]'),
#  Text(0.8990147783251231, 0.475, 'x[3] <= 2.05\ngini = 0.352\nsamples = 38\nvalue = [3, 48, 10, 0, 0]'),
#  Text(0.8940886699507389, 0.425, 'gini = 0.0\nsamples = 9\nvalue = [0, 16, 0, 0, 0]'),
#  Text(0.9039408866995073, 0.425, 'x[10] <= 10.15\ngini = 0.44\nsamples = 29\nvalue = [3, 32, 10, 0, 0]'),
#  Text(0.8990147783251231, 0.375, 'x[6] <= 67.0\ngini = 0.364\nsamples = 27\nvalue = [3, 32, 6, 0, 0]'),
#  Text(0.8842364532019704, 0.325, 'x[1] <= 0.61\ngini = 0.512\nsamples = 13\nvalue = [1, 11, 6, 0, 0]'),
#  Text(0.8793103448275862, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.8891625615763546, 0.275, 'x[8] <= 3.3\ngini = 0.418\nsamples = 11\nvalue = [1, 11, 3, 0, 0]'),
#  Text(0.8842364532019704, 0.225, 'gini = 0.0\nsamples = 4\nvalue = [0, 8, 0, 0, 0]'),
#  Text(0.8940886699507389, 0.225, 'x[2] <= 0.115\ngini = 0.612\nsamples = 7\nvalue = [1, 3, 3, 0, 0]'),
#  Text(0.8891625615763546, 0.175, 'x[8] <= 3.475\ngini = 0.56\nsamples = 5\nvalue = [1, 1, 3, 0, 0]'),
#  Text(0.8842364532019704, 0.125, 'x[3] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3, 0, 0]'),
#  Text(0.8793103448275862, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8891625615763546, 0.075, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.8940886699507389, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.8990147783251231, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.9137931034482759, 0.325, 'x[7] <= 0.997\ngini = 0.159\nsamples = 14\nvalue = [2, 21, 0, 0, 0]'),
#  Text(0.9088669950738916, 0.275, 'x[8] <= 3.175\ngini = 0.444\nsamples = 2\nvalue = [2, 1, 0, 0, 0]'),
#  Text(0.9039408866995073, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.9137931034482759, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.9187192118226601, 0.275, 'gini = 0.0\nsamples = 12\nvalue = [0, 20, 0, 0, 0]'),
#  Text(0.9088669950738916, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0]'),
#  Text(0.9187192118226601, 0.475, 'x[8] <= 3.155\ngini = 0.444\nsamples = 7\nvalue = [0, 3, 6, 0, 0]'),
#  Text(0.9137931034482759, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.9236453201970444, 0.425, 'x[1] <= 0.615\ngini = 0.245\nsamples = 6\nvalue = [0, 1, 6, 0, 0]'),
#  Text(0.9187192118226601, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.9285714285714286, 0.375, 'x[9] <= 0.825\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0]'),
#  Text(0.9236453201970444, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.9334975369458128, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.9618226600985221, 0.825, 'x[4] <= 0.082\ngini = 0.559\nsamples = 47\nvalue = [4, 26, 43, 2, 1]'),
#  Text(0.9334975369458128, 0.775, 'x[6] <= 55.5\ngini = 0.543\nsamples = 22\nvalue = [2, 20, 16, 0, 0]'),
#  Text(0.9285714285714286, 0.725, 'x[0] <= 6.75\ngini = 0.461\nsamples = 18\nvalue = [2, 20, 7, 0, 0]'),
#  Text(0.9187192118226601, 0.675, 'x[1] <= 0.78\ngini = 0.656\nsamples = 5\nvalue = [2, 3, 3, 0, 0]'),
#  Text(0.9137931034482759, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.9236453201970444, 0.625, 'x[2] <= 0.06\ngini = 0.48\nsamples = 3\nvalue = [2, 0, 3, 0, 0]'),
#  Text(0.9187192118226601, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.9285714285714286, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0]'),
#  Text(0.9384236453201971, 0.675, 'x[8] <= 3.13\ngini = 0.308\nsamples = 13\nvalue = [0, 17, 4, 0, 0]'),
#  Text(0.9334975369458128, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.9433497536945813, 0.625, 'x[5] <= 13.5\ngini = 0.255\nsamples = 12\nvalue = [0, 17, 3, 0, 0]'),
#  Text(0.9384236453201971, 0.575, 'x[5] <= 5.5\ngini = 0.397\nsamples = 7\nvalue = [0, 8, 3, 0, 0]'),
#  Text(0.9334975369458128, 0.525, 'x[3] <= 2.25\ngini = 0.198\nsamples = 5\nvalue = [0, 8, 1, 0, 0]'),
#  Text(0.9285714285714286, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.9384236453201971, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 8, 0, 0, 0]'),
#  Text(0.9433497536945813, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.9482758620689655, 0.575, 'gini = 0.0\nsamples = 5\nvalue = [0, 9, 0, 0, 0]'),
#  Text(0.9384236453201971, 0.725, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 9, 0, 0]'),
#  Text(0.9901477832512315, 0.775, 'x[1] <= 0.898\ngini = 0.464\nsamples = 25\nvalue = [2, 6, 27, 2, 1]'),
#  Text(0.9852216748768473, 0.725, 'x[5] <= 33.5\ngini = 0.437\nsamples = 24\nvalue = [1, 6, 27, 2, 1]'),
#  Text(0.9802955665024631, 0.675, 'x[8] <= 3.42\ngini = 0.407\nsamples = 23\nvalue = [1, 6, 27, 1, 1]'),
#  Text(0.9753694581280788, 0.625, 'x[2] <= 0.44\ngini = 0.515\nsamples = 18\nvalue = [1, 6, 17, 1, 1]'),
#  Text(0.9630541871921182, 0.575, 'x[2] <= 0.13\ngini = 0.588\nsamples = 12\nvalue = [1, 6, 9, 1, 0]'),
#  Text(0.9532019704433498, 0.525, 'x[6] <= 20.0\ngini = 0.245\nsamples = 5\nvalue = [1, 0, 6, 0, 0]'),
#  Text(0.9482758620689655, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.958128078817734, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 6, 0, 0]'),
#  Text(0.9729064039408867, 0.525, 'x[9] <= 0.67\ngini = 0.54\nsamples = 7\nvalue = [0, 6, 3, 1, 0]'),
#  Text(0.9679802955665024, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [0, 6, 0, 0, 0]'),
#  Text(0.9778325123152709, 0.475, 'x[10] <= 11.25\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3, 1, 0]'),
#  Text(0.9729064039408867, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0]'),
#  Text(0.9827586206896551, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.9876847290640394, 0.575, 'x[10] <= 13.35\ngini = 0.198\nsamples = 6\nvalue = [0, 0, 8, 0, 1]'),
#  Text(0.9827586206896551, 0.525, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 8, 0, 0]'),
#  Text(0.9926108374384236, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.9852216748768473, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 10, 0, 0]'),
#  Text(0.9901477832512315, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.9950738916256158, 0.725, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]')]

# %%
plt.figure(figsize=(20,30))
for i in range(len(rf_classificationModel.estimators_)):
    tree.plot_tree(rf_classificationModel.estimators_[0],filled=True)
